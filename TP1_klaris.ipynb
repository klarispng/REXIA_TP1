# %% [markdown]
# ## REXIA - TP1 : Données tabulaires
#
# ### DEBRAY Clarisse & GLERANT Pierre
# ##### clarisse.debray@student-cs.fr -  pierre.glerant@student-cs.fr

# %%
import pickle
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
X = pd.read_pickle("dataset_RH.pkl")[0]
y = pd.read_pickle("dataset_RH.pkl")[1]

df = X.copy()
df["demission"] = y

# %% [markdown]
# ### 1) Analyse du jeu de données
